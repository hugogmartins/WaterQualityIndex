# %% [markdown]
# - Metodo para salvar os dados já separados.

# %%
def save_data_select(df):
  data = df.to_csv("/Users/arthurhenrique/Documentos/pessoal/faculdade/documentos/tcc/repository/machine-learning-water-quality/notebook/output/concatenated/output_select_parameters_.csv", index=False)

# %% [markdown]
# - Juntando todos os csv gerados.

# %%
import glob
import pandas as pd

all_filenames = glob.glob('/Users/arthurhenrique/Documentos/pessoal/faculdade/documentos/tcc/repository/machine-learning-water-quality/notebook/output/*.csv')

combined_csv = pd.concat([pd.read_csv(f, dtype=str) for f in all_filenames ], ignore_index=True)

combined_csv.to_csv("/Users/arthurhenrique/Documentos/pessoal/faculdade/documentos/tcc/repository/machine-learning-water-quality/notebook/output/concatenated/combined_csv.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[2], line 6
#       2 import pandas as pd
#       4 all_filenames = glob.glob('/Users/arthurhenrique/Documentos/pessoal/faculdade/documentos/tcc/repository/machine-learning-water-quality/notebook/output/*.csv')
# ----> 6 combined_csv = pd.concat([pd.read_csv(f, dtype=str) for f in all_filenames ], ignore_index=True)
#       8 combined_csv.to_csv("/Users/arthurhenrique/Documentos/pessoal/faculdade/documentos/tcc/repository/machine-learning-water-quality/notebook/output/concatenated/combined_csv.csv", index=False)
#
# ...

# %% [markdown]
# - Separacão dos dados para analise:
#   - Dissolved oxygen, mg/L
#   - pH
#   - Conductivity, _S/cm
#   - Nitrate, mg/L
#   - Biological oxygen demand, mg/L
#   - Fecal coliform/100 mL
#   - Total coliform/100 mL

# %%
import pandas as pd
import csv

data = pd.read_csv('/Users/arthurhenrique/Documentos/pessoal/faculdade/documentos/tcc/repository/machine-learning-water-quality/notebook/output/output_sao_francisco_base_completa.csv', low_memory=False, delim_whitespace=False)
dt_select_columns = data[["17_OD_mgl_02", "18_PH", "50_Condutivida_de_Eletrica_us_cm_a_20c", "13_Nitratos_mgl_n)", "46_Coliformes_Fecais_nmp_100ml", "47_Coliformes_Totais_nmp_100ml","7_DBO_mgl_02)"]]


save_data_select(dt_select_columns)
# Out:
# /var/folders/5j/y78gd57x17n5wslbx8s54x380000gn/T/ipykernel_70839/756136901.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv('/Users/arthurhenrique/Documentos/pessoal/faculdade/documentos/tcc/repository/machine-learning-water-quality/notebook/output/output_sao_francisco_base_completa.csv', low_memory=False, delim_whitespace=False)
